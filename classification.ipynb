# %% [markdown]
# # **📁 Import Libraries & Load Data**

# %%
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset('titanic')
data = data.dropna()
data.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %% [markdown]
# # **⚙️ Set Up PyCaret for Classification**

# %%
from pycaret.classification import *

classification_setup = setup(
    data=data,
    target = 'survived',
    session_id = 123,
    verbose = False
)

# %% [markdown]
# # **🤖 Compare All Models and Select the Best One**

# %%
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             06:32:57
# Status     . . . . . . . . . . . . . . . . . .    Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_49f55 th {
#   text-align: left;
# }
# #T_49f55_row0_col0, #T_49f55_row1_col0, #T_49f55_row2_col0, #T_49f55_row3_col0, #T_49f55_row4_col0, #T_49f55_row5_col0, #T_49f55_row6_col0, #T_49f55_row6_col1, #T_49f55_row6_col4, #T_49f55_row6_col5, #T_49f55_row6_col6, #T_49f55_row6_col7, #T_49f55_row7_col0, #T_49f55_row7_col1, #T_49f55_row7_col2, #T_49f55_row7_col4, #T_49f55_row7_col5, #T_49f55_row7_col6, #T_49f55_row7_col7, #T_49f55_row8_col0, #T_49f55_row8_col1, #T_49f55_row8_col4, #T_49f55_row8_col5, #T_49f55_row8_col6, #T_49f55_row8_col7, #T_49f55_row9_col0, #T_49f55_row9_col1, #T_49f55_row9_col4, #T_49f55_row9_col5, #T_49f55_row9_col6, #T_49f55_row9_col7, #T_49f55_row10_col0, #T_49f55_row10_col1, #T_49f55_row10_col2, #T_49f55_row10_col3, #T_49f55_row10_col4, #T_49f55_row10_col5, #T_49f55_row10_col6, #T_49f55_row10_col7, #T_49f55_row11_col0, #T_49f55_row11_col1, #T_49f55_row11_col2, #T_49f55_row11_col3, #T_49f55_row11_col4, #T_49f55_row11_col5, #T_49f55_row11_col6, #T_49f55_row11_col7, #T_49f55_row12_col0, #T_49f55_row12_col1, #T_49f55_row12_col2, #T_49f55_row12_col4, #T_49f55_row12_col5, #T_49f55_row12_col6, #T_49f55_row12_col7, #T_49f55_row13_col0, #T_49f55_row13_col1, #T_49f55_row13_col2, #T_49f55_row13_col3, #T_49f55_row13_col4, #T_49f55_row13_col5, #T_49f55_row13_col6, #T_49f55_row13_col7 {
#   text-align: left;
# }
# #T_49f55_row0_col1, #T_49f55_row0_col2, #T_49f55_row0_col3, #T_49f55_row0_col4, #T_49f55_row0_col5, #T_49f55_row0_col6, #T_49f55_row0_col7, #T_49f55_row1_col1, #T_49f55_row1_col2, #T_49f55_row1_col3, #T_49f55_row1_col4, #T_49f55_row1_col5, #T_49f55_row1_col6, #T_49f55_row1_col7, #T_49f55_row2_col1, #T_49f55_row2_col2, #T_49f55_row2_col3, #T_49f55_row2_col4, #T_49f55_row2_col5, #T_49f55_row2_col6, #T_49f55_row2_col7, #T_49f55_row3_col1, #T_49f55_row3_col2, #T_49f55_row3_col3, #T_49f55_row3_col4, #T_49f55_row3_col5, #T_49f55_row3_col6, #T_49f55_row3_col7, #T_49f55_row4_col1, #T_49f55_row4_col2, #T_49f55_row4_col3, #T_49f55_row4_col4, #T_49f55_row4_col5, #T_49f55_row4_col6, #T_49f55_row4_col7, #T_49f55_row5_col1, #T_49f55_row5_col2, #T_49f55_row5_col3, #T_49f55_row5_col4, #T_49f55_row5_col5, #T_49f55_row5_col6, #T_49f55_row5_col7, #T_49f55_row6_col2, #T_49f55_row6_col3, #T_49f55_row7_col3, #T_49f55_row8_col2, #T_49f55_row8_col3, #T_49f55_row9_col2, #T_49f55_row9_col3, #T_49f55_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_49f55_row0_col8, #T_49f55_row1_col8, #T_49f55_row2_col8, #T_49f55_row4_col8, #T_49f55_row5_col8, #T_49f55_row6_col8, #T_49f55_row7_col8, #T_49f55_row8_col8, #T_49f55_row9_col8, #T_49f55_row10_col8, #T_49f55_row11_col8, #T_49f55_row12_col8, #T_49f55_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_49f55_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_49f55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49f55_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_49f55_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_49f55_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_49f55_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_49f55_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_49f55_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_49f55_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_49f55_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_49f55_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49f55_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_49f55_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_49f55_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_49f55_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_49f55_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_49f55_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_49f55_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_49f55_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_49f55_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_49f55_row0_col8" class="data row0 col8" >1.2970</td>
#     </tr>
#     <tr>
#       <th id="T_49f55_level0_row1" class="row_heading level0 row1" >dt</th>
#       <td id="T_49f55_row1_col0" class="data row1 col0" >Decision Tree Classifier</td>
#       <td id="T_49f55_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_49f55_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_49f55_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_49f55_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_49f55_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_49f55_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_49f55_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_49f55_row1_col8" class="data row1 col8" >0.0910</td>
#     </tr>
#     <tr>
#       <th id="T_49f55_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_49f55_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_49f55_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_49f55_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_49f55_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_49f55_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_49f55_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_49f55_row2_col6" class="data row2 col6" >1.0000</td>
#       <td id="T_49f55_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_49f55_row2_col8" class="data row2 col8" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_49f55_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_49f55_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_49f55_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_49f55_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_49f55_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_49f55_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_49f55_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_49f55_row3_col6" class="data row3 col6" >1.0000</td>
#       <td id="T_49f55_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_49f55_row3_col8" class="data row3 col8" >0.0450</td>
#     </tr>
#     <tr>
#       <th id="T_49f55_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_49f55_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_49f55_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_49f55_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_49f55_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_49f55_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_49f55_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_49f55_row4_col6" class="data row4 col6" >1.0000</td>
#       <td id="T_49f55_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_49f55_row4_col8" class="data row4 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_49f55_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_49f55_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_49f55_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_49f55_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_49f55_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_49f55_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_49f55_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_49f55_row5_col6" class="data row5 col6" >1.0000</td>
#       <td id="T_49f55_row5_col7" class="data row5 col7" >1.0000</td>
#       <td id="T_4

# %% [markdown]
# # **📈 Evaluate the Best Model Visually**

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # **✅ Finalize the Best Model**

# %%
final_model = finalize_model(best_model)

# %% [markdown]
# # **💾 Save the Model for Future Use**

# %%
save_model(final_model , 'best_classification_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['pclass', 'age', 'sibsp', 'parch',
#                                               'fare'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['sex...
#                   TransformerWrapper(exclude=None,
#                                      include=['embarked', 'class', 'who', 'deck',
#                                               'embark_town'],
#                                      transformer=OneHotEncoder(cols=['embarked',
#                                                                      'class',
#                                                                      'who',
#                                                                      'deck',
#                                                                      'embark_town'],
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                return_df=True,
#                                                                use_cat_names=True,
#                                                                verbose=0))),
#                  ('actual_estimator',
#                   GaussianNB(priors=None, var_smoothing=1e-09))],
#           verbose=False),
#  'best_classification_model.pkl')

# %% [markdown]
# # **🧪 Make Predictions on New or Existing Data**

# %%
predictions = predict_model(final_model, data=data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_72e49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72e49_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_72e49_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_72e49_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_72e49_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_72e49_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_72e49_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_72e49_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_72e49_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72e49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72e49_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_72e49_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_72e49_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_72e49_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_72e49_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_72e49_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_72e49_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_72e49_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions.head()
# Out:
#     pclass     sex   age  sibsp  parch       fare embarked  class    who  \
# 1        1  female  38.0      1      0  71.283302        C  First  woman
# 3        1  female  35.0      1      0  53.099998        S  First  woman
# 6        1    male  54.0      0      0  51.862499        S  First    man
# 10       3  female   4.0      1      1  16.700001        S  Third  child
# 11       1  female  58.0      0      0  26.549999        S  First  woman
#
#     adult_male deck  embark_town alive  alone  survived  prediction_label  \
# 1        False    C    Cherbourg   yes  False         1                 1
# 3        False    C  Southampton   yes  False         1                 1
# 6         True    E  Southampton    no   True         0                 0
# 10       False    G  Southampton   yes  False         1                 1
# 11       False    C  Southampton   yes   True         1                 1
#
#     prediction_score
# 1                1.0
# 3                1.0
# 6                1.0
# 10               1.0
# 11               1.0

# %% [markdown]
# # **ThankYou**
